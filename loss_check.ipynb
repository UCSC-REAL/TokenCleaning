# %% [markdown]
# ## Check the loss diff manually

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
import torch
from functools import partial

def encode_with_prompt_completion_format(example, tokenizer, max_seq_length, add_bos=False):
    '''
    Here we assume each example has 'prompt' and 'completion' fields.
    We concatenate prompt and completion and tokenize them together because otherwise prompt will be padded/trancated 
    and it doesn't make sense to follow directly with the completion.
    '''
    # if prompt doesn't end with space and completion doesn't start with space, add space
    if not example['prompt'].endswith((' ', '\n', '\t')) and not example['completion'].startswith((' ', '\n', '\t')):
        example_text = example['prompt'] + ' ' + example['completion']
    else:
        example_text = example['prompt'] + example['completion']
    example_text = example_text + tokenizer.eos_token
    if add_bos:
        example_text = tokenizer.bos_token + example_text
    tokenized_example = tokenizer(example_text, return_tensors='pt', max_length=max_seq_length, truncation=True)
    input_ids = tokenized_example.input_ids
    labels = input_ids.clone()
    tokenized_prompt = tokenizer(example['prompt'], return_tensors='pt', max_length=max_seq_length, truncation=True)
    # mask the prompt part for avoiding loss
    # labels[:, :tokenized_prompt.input_ids.shape[1]] = -100
    attention_mask = torch.ones_like(input_ids)
    return {
        'input_ids': input_ids.flatten(),
        'labels': labels.flatten(),
        'attention_mask': attention_mask.flatten(),
    }


def encode_with_messages_format(example, tokenizer, max_seq_length, add_bos=False):
    '''
    Here we assume each example has a 'messages' field Each message is a dict with 'role' and 'content' fields.
    We concatenate all messages with the roles as delimiters and tokenize them together.
    '''
    messages = example['messages']
    if len(messages) == 0:
        raise ValueError('messages field is empty.')
    
    def _concat_messages(messages):
        message_text = ""
        for message in messages:
            if message["role"] == "system":
                message_text += "<|system|>\n" + message["content"].strip() + "\n"
            elif message["role"] == "user":
                message_text += "<|user|>\n" + message["content"].strip() + "\n"
            elif message["role"] == "assistant":
                message_text += "<|assistant|>\n" + message["content"].strip() + tokenizer.eos_token + "\n"
            else:
                raise ValueError("Invalid role: {}".format(message["role"]))
        return message_text
        
    example_text = _concat_messages(messages).strip()
    if add_bos:
        example_text = tokenizer.bos_token + example_text
    tokenized_example = tokenizer(example_text, return_tensors='pt', max_length=max_seq_length, truncation=True)
    input_ids = tokenized_example.input_ids
    labels = input_ids.clone()

    # mask the non-assistant part for avoiding loss
    for message_idx, message in enumerate(messages):
        if message["role"] != "assistant":
            if message_idx == 0:
                message_start_idx = 0
            else:
                message_start_idx = tokenizer(
                    _concat_messages(messages[:message_idx]), return_tensors='pt', max_length=max_seq_length, truncation=True
                ).input_ids.shape[1]
            if message_idx < len(messages) - 1 and messages[message_idx+1]["role"] == "assistant":
                # here we also ignore the role of the assistant
                messages_so_far = _concat_messages(messages[:message_idx+1]) + "<|assistant|>\n"
            else:
                messages_so_far = _concat_messages(messages[:message_idx+1])
            message_end_idx = tokenizer(
                messages_so_far,
                return_tensors='pt', 
                max_length=max_seq_length, 
                truncation=True
            ).input_ids.shape[1]
            # labels[:, message_start_idx:message_end_idx] = -100

            if message_end_idx >= max_seq_length:
                break

    attention_mask = torch.ones_like(input_ids)
    return {
        'input_ids': input_ids.flatten(),
        'labels': labels.flatten(),
        'attention_mask': attention_mask.flatten(),
    }

# dataset_name='test_dataset'
dataset_name = 'filtered-cured-50k-all-iter-sample-subset-small-new_6'

model_name_or_path = "meta-llama/Llama-3.2-3B"
data_path = f"selected_data/{dataset_name}.json"

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)
raw_dataset = load_dataset("json", data_files=data_path)

if "prompt" in raw_dataset["train"].column_names and "completion" in raw_dataset["train"].column_names:
    encode_function = partial(
        encode_with_prompt_completion_format,
        tokenizer=tokenizer,
        max_seq_length= 2048,
        add_bos= False,
    )
elif "messages" in raw_dataset["train"].column_names:
    encode_function = partial(
        encode_with_messages_format,
        tokenizer=tokenizer,
        max_seq_length= 2048,
        add_bos= False,
    )
    
raw_dataset = raw_dataset.map(
    lambda example, idx: {"idx": idx},
    with_indices=True,  
    desc="Adding idx column",
)
        

lm_datasets = raw_dataset.map(
    encode_function,
    batched=False,
    # remove_columns=[name for name in raw_dataset["train"].column_names if name not in ["idx", "input_ids", "labels", "attention_mask"]],
    desc="Tokenizing and reformatting instruction data",
)

train_dataset = lm_datasets['train']
raw_labels = train_dataset['labels']
# Out:
# Adding idx column:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Tokenizing and reformatting instruction data:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
import torch
import numpy as np


def get_global_top_k_indices(data, k):

    flattened = [(value, i, j) for i, sublist in enumerate(data) for j, value in enumerate(sublist)]
    
    top_k = sorted(flattened, key=lambda x: x[0], reverse=True)[:k] ##loss
    
    top_k_indices = [(item[1], item[2]+1) for item in top_k]  #item[2]+1 fix the first label biased to match the position
    return top_k_indices



data_type = 'filtered-cured-50k-all-iter-sample-subset-small-new_6'
model_type = 'filtered-cured-50k-all-iter-sample-subset-small-new_4'
new_model_type ='filtered-cured-50k-all-iter-sample-subset-small-new_5'
data_prop=0.2

losses_pre = torch.load(f"results/loss/token_losses_{data_type}_{model_type}.pt")
losses_cur = torch.load(f"results/loss/token_losses_{data_type}_{new_model_type}.pt")

# initialize: ignore all tokens
selected_labels = [[-100 for _ in range(len(label))] for label in raw_labels]

##the calculation different loss of two models

loss_diff = [(np.array(loss1) - np.array(loss2)).tolist() for loss1, loss2 in zip(losses_pre, losses_cur)]

all_token_count = sum(len(label) for label in raw_labels)
print(f"#### all token counting: {all_token_count}\n")

print(f"model pair: ({model_type}, {new_model_type}) -- dataset: {data_type}")


#### selected pattern    
selected_global_labels = [[-100 for _ in range(len(label))] for label in raw_labels]
select_global_tokens_indices = get_global_top_k_indices(loss_diff, int(all_token_count * data_prop))
for i, j in select_global_tokens_indices:
        selected_global_labels[i][j] = raw_labels[i][j] 

### sample-level 
selected_sample_labels = [[-100 for _ in range(len(label))] for label in raw_labels]
select_sample_tokens_indices = []
for diff in loss_diff:
    _, indices = torch.topk(torch.tensor(diff), k=int(len(diff) * data_prop), largest=True)
    select_sample_tokens_indices.append((indices + 1).tolist()) ## indices +1 represents the biased value, which match the real token in the original dataset    
for i, (selected_indices, label) in enumerate(zip(select_sample_tokens_indices, raw_labels)):
    for j in selected_indices:
        selected_sample_labels[i][j] = label[j]

                
    
# 计算相似比例
valid_match_count = 0
valid_union_count = 0

all_token_count = sum(len(label) for label in selected_sample_labels)

for sample_labels, global_labels in zip(selected_sample_labels, selected_global_labels):
    # 确保两个列表对齐比较（以较短的长度为准）
    for sl, gl in zip(sample_labels, global_labels):
        if sl == gl and sl != -100:
            valid_match_count += 1
        if sl != -100 or gl !=-100:
            valid_union_count +=1

# 计算相似比例
similarity_ratio = valid_match_count / all_token_count 
union_ratio = valid_union_count / all_token_count 

print(f"Similarity ratio: {similarity_ratio:.2%}")
print(f"Union ratio: {union_ratio:.2%}")
# Out:
# /tmp/ipykernel_2493441/2995865510.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   losses_pre = torch.load(f"results/loss/token_losses_{data_type}_{model_type}.pt")
# /tmp/ipykernel_2493441/2995865510.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   losses_cur = torch.load(f"results/loss/token_losses_{data_type}_{new_model_type}.pt")
# #### all token counting: 487626
#
# model pair: (filtered-cured-50k-all-iter-sample-subset-small-new_4, filtered-cured-50k-all-iter-sample-subset-small-new_5) -- dataset: filtered-cured-50k-all-iter-sample-subset-small-new_6
# Similarity ratio: 18.02%
# Union ratio: 21.85%

# %%
for loss, labels in zip(loss_diff, raw_labels):
    print(f"len loss: {len(loss)} -- len labels: {len(labels)}")
# Out:
# len loss: 72 -- len labels: 73
# len loss: 1322 -- len labels: 1323
# len loss: 231 -- len labels: 232
# len loss: 167 -- len labels: 168
# len loss: 337 -- len labels: 338
# len loss: 272 -- len labels: 273
# len loss: 435 -- len labels: 436
# len loss: 121 -- len labels: 122
# len loss: 250 -- len labels: 251
# len loss: 113 -- len labels: 114
# len loss: 46 -- len labels: 47
# len loss: 223 -- len labels: 224
# len loss: 788 -- len labels: 789
# len loss: 311 -- len labels: 312
# len loss: 199 -- len labels: 200
# len loss: 530 -- len labels: 531
# len loss: 468 -- len labels: 469
# len loss: 67 -- len labels: 68
# len loss: 682 -- len labels: 683
# len loss: 342 -- len labels: 343
# len loss: 549 -- len labels: 550
# len loss: 418 -- len labels: 419
# len loss: 423 -- len labels: 424
# len loss: 125 -- len labels: 126
# len loss: 32 -- len labels: 33
# len loss: 142 -- len labels: 143
# len loss: 797 -- len labels: 798
# len loss: 925 -- len labels: 926
# len loss: 621 -- len labels: 622
# len loss: 712 -- len labels: 713
# len loss: 359 -- len labels: 360
# len loss: 680 -- len labels: 681
# len loss: 394 -- len labels: 395
# len loss: 342 -- len labels: 343
# len loss: 335 -- len labels: 336
# len loss: 870 -- len labels: 871
# len loss: 366 -- len labels: 367
# len loss: 463 -- len labels: 464
# len loss: 407 -- len labels: 408
# len loss: 318 -- len labels: 319
# len loss: 545 -- len labels: 546
# len loss: 28 -- len labels: 29
# len loss: 512 -- len labels: 513
# len loss: 857 -- len labels: 858
# len loss: 545 -- len labels: 546
# len loss: 715 -- len labels: 716
# len loss: 543 -- len labels: 544
# len loss: 470 -- len labels: 471
# len loss: 857 -- len labels: 858
# len loss: 404 -- len labels: 405
# len loss: 416 -- len labels: 417
# len loss: 349 -- len labels: 350
# len loss: 305 -- len labels: 306
# len loss: 1323 -- len labels: 1324
# len loss: 444 -- len labels: 445
# len loss: 260 -- len labels: 261
# len loss: 1034 -- len labels: 1035
# len loss: 87 -- len labels: 88
# len loss: 838 -- len labels: 839
# len loss: 148 -- len labels: 149
# len loss: 105 -- len labels: 106
# len loss: 349 -- len labels: 350
# len loss: 960 -- len labels: 961
# len loss: 525 -- len labels: 526
# len loss: 93 -- len labels: 94
# len loss: 737 -- len labels: 738
# len loss: 480 -- len labels: 481
# len loss: 672 -- len labels: 673
# len loss: 367 -- len labels: 368
# len loss: 101 -- len labels: 102
# len loss: 710 -- len labels: 711
# len loss: 463 -- len labels: 464
# len loss: 302 -- len labels: 303
# len loss: 362 -- len labels: 363
# len loss: 111 -- len labels: 112
# len loss: 1460 -- len labels: 1461
# len loss: 522 -- len labels: 523
# len loss: 261 -- len labels: 262
# len loss: 494 -- len labels: 495
# len loss: 303 -- len labels: 304
# len loss: 316 -- len labels: 317
# len loss: 501 -- len labels: 502
# len loss: 308 -- len labels: 309
# len loss: 355 -- len labels: 356
# len loss: 300 -- len labels: 301
# len loss: 526 -- len labels: 527
# len loss: 97 -- len labels: 98
# len loss: 329 -- len labels: 330
# len loss: 126 -- len labels: 127
# len loss: 579 -- len labels: 580
# len loss: 424 -- len labels: 425
# len loss: 147 -- len labels: 148
# len loss: 639 -- len labels: 640
# len loss: 495 -- len labels: 496
# len loss: 78 -- len labels: 79
# len loss: 197 -- len labels: 198
# len loss: 483 -- len labels: 484
# len loss: 688 -- len labels: 689
# len loss: 1753 -- len labels: 1754
# len loss: 163 -- len labels: 164
# len loss: 551 -- len labels: 552
# len loss: 113 -- len labels: 114
# len loss: 469 -- len labels: 470
# len loss: 47 -- len labels: 48
# len loss: 43 -- len labels: 44
# len loss: 1288 -- len labels: 1289
# len loss: 809 -- len labels: 810
# len loss: 281 -- len labels: 282
# len loss: 510 -- len labels: 511
# len loss: 157 -- len labels: 158
# len loss: 445 -- len labels: 446
# len loss: 138 -- len labels: 139
# len loss: 254 -- len labels: 255
# len loss: 305 -- len labels: 306
# len loss: 996 -- len labels: 997
# len loss: 574 -- len labels: 575
# len loss: 586 -- len labels: 587
# len loss: 673 -- len labels: 674
# len loss: 1311 -- len labels: 1312
# len loss: 85 -- len labels: 86
# len loss: 787 -- len labels: 788
# len loss: 722 -- len labels: 723
# len loss: 705 -- len labels: 706
# len loss: 535 -- len labels: 536
# len loss: 431 -- len labels: 432
# len loss: 96 -- len labels: 97
# len loss: 128 -- len labels: 129
# len loss: 518 -- len labels: 519
# len loss: 575 -- len labels: 576
# len loss: 322 -- len labels: 323
# len loss: 501 -- len labels: 502
# len loss: 668 -- len labels: 669
# len loss: 112 -- len labels: 113
# len loss: 470 -- len labels: 471
# len loss: 542 -- len labels: 543
# len loss: 750 -- len labels: 751
# len loss: 932 -- len labels: 933
# len loss: 373 -- len labels: 374
# len loss: 625 -- len labels: 626
# len loss: 301 -- len labels: 302
# len loss: 882 -- len labels: 883
# len loss: 466 -- len labels: 467
# len loss: 162 -- len labels: 163
# len loss: 299 -- len labels: 300
# len loss: 115 -- len labels: 116
# len loss: 724 -- len labels: 725
# len loss: 1068 -- len labels: 1069
# len loss: 1156 -- len labels: 1157
# len loss: 66 -- len labels: 67
# len loss: 496 -- len labels: 497
# len loss: 654 -- len labels: 655
# len loss: 1829 -- len labels: 1830
# len loss: 1401 -- len labels: 1402
# len loss: 100 -- len labels: 101
# len loss: 56 -- len labels: 57
# len loss: 338 -- len labels: 339
# len loss: 489 -- len labels: 490
# len loss: 398 -- len labels: 399
# len loss: 519 -- len labels: 520
# len loss: 840 -- len labels: 841
# len loss: 856 -- len labels: 857
# len loss: 421 -- len labels: 422
# len loss: 113 -- len labels: 114
# len loss: 95 -- len labels: 96
# len loss: 71 -- len labels: 72
# len loss: 500 -- len labels: 501
# len loss: 557 -- len labels: 558
# len loss: 109 -- len labels: 110
# len loss: 596 -- len labels: 597
# len loss: 446 -- len labels: 447
# len loss: 338 -- len labels: 339
# len loss: 138 -- len labels: 139
# len loss: 540 -- len labels: 541
# len loss: 738 -- len labels: 739
# len loss: 605 -- len labels: 606
# len loss: 264 -- len labels: 265
# len loss: 76 -- len labels: 77
# len loss: 687 -- len labels: 688
# len loss: 92 -- len labels: 93
# len loss: 1149 -- len labels: 1150
# len loss: 496 -- len labels: 497
# len loss: 753 -- len labels: 754
# len loss: 446 -- len labels: 447
# len loss: 164 -- len labels: 165
# len loss: 647 -- len labels: 648
# len loss: 602 -- len labels: 603
# len loss: 271 -- len labels: 272
# len loss: 638 -- len labels: 639
# len loss: 647 -- len labels: 648
# len loss: 405 -- len labels: 406
# len loss: 1199 -- len labels: 1200
# len loss: 206 -- len labels: 207
# len loss: 455 -- len labels: 456
# len loss: 605 -- len labels: 606
# len loss: 364 -- len labels: 365
# len loss: 507 -- len labels: 508
# len loss: 208 -- len labels: 209
# len loss: 476 -- len labels: 477
# len loss: 393 -- len labels: 394
# len loss: 506 -- len labels: 507
# len loss: 78 -- len labels: 79
# len loss: 112 -- len labels: 113
# len loss: 1069 -- len labels: 1070
# len loss: 473 -- len labels: 474
# len loss: 909 -- len labels: 910
# len loss: 680 -- len labels: 681
# len loss: 244 -- len labels: 245
# len loss: 284 -- len labels: 285
# len loss: 463 -- len labels: 464
# len loss: 514 -- len labels: 515
# len loss: 584 -- len labels: 585
# len loss: 569 -- len labels: 570
# len loss: 442 -- len labels: 443
# len loss: 866 -- len labels: 867
# len loss: 999 -- len labels: 1000
# len loss: 528 -- len labels: 529
# len loss: 519 -- len labels: 520
# len loss: 530 -- len labels: 531
# len loss: 531 -- len labels: 532
# len loss: 449 -- len labels: 450
# len loss: 864 -- len labels: 865
# len loss: 50 -- len labels: 51
# len loss: 385 -- len labels: 386
# len loss: 1728 -- len labels: 1729
# len loss: 503 -- len labels: 504
# len loss: 124 -- len labels: 125
# len loss: 241 -- len labels: 242
# len loss: 354 -- len labels: 355
# len loss: 326 -- len labels: 327
# len loss: 707 -- len labels: 708
# len loss: 443 -- len labels: 444
# len loss: 723 -- len labels: 724
# len loss: 276 -- len labels: 277
# len loss: 604 -- len labels: 605
# len loss: 1051 -- len labels: 1052
# len loss: 113 -- len labels: 114
# len loss: 73 -- len labels: 74
# len loss: 536 -- len labels: 537
# len loss: 429 -- len labels: 430
# len loss: 152 -- len labels: 153
# len loss: 357 -- len labels: 358
# len loss: 780 -- len labels: 781
# len loss: 229 -- len labels: 230
# len loss: 621 -- len labels: 622
# len loss: 576 -- len labels: 577
# len loss: 89 -- len labels: 90
# len loss: 395 -- len labels: 396
# len loss: 121 -- len labels: 122
# len loss: 58 -- len labels: 59
# len loss: 1143 -- len labels: 1144
# len loss: 466 -- len labels: 467
# len loss: 631 -- len labels: 632
# len loss: 59 -- len labels: 60
# len loss: 966 -- len labels: 967
# len loss: 477 -- len labels: 478
# len loss: 617 -- len labels: 618
# len loss: 72 -- len labels: 73
# len loss: 468 -- len labels: 469
# len loss: 155 -- len labels: 156
# len loss: 202 -- len labels: 203
# len loss: 389 -- len labels: 390
# len loss: 337 -- len labels: 338
# len loss: 185 -- len labels: 186
# len loss: 137 -- len labels: 138
# len loss: 140 -- len labels: 141
# len loss: 368 -- len labels: 369
# len loss: 394 -- len labels: 395
# len loss: 429 -- len labels: 430
# len loss: 522 -- len labels: 523
# len loss: 326 -- len labels: 327
# len loss: 96 -- len labels: 97
# len loss: 995 -- len labels: 996
# len loss: 521 -- len labels: 522
# len loss: 519 -- len labels: 520
# len loss: 936 -- len labels: 937
# len loss: 213 -- len labels: 214
# len loss: 330 -- len labels: 331
# len loss: 554 -- len labels: 555
# len loss: 251 -- len labels: 252
# len loss: 313 -- len labels: 314
# len loss: 74 -- len labels: 75
# len loss: 709 -- len labels: 710
# len loss: 349 -- len labels: 350
# len loss: 80 -- len labels: 81
# len loss: 639 -- len labels: 640
# len loss: 510 -- len labels: 511
# len loss: 135 -- len labels: 136
# len loss: 94 -- len labels: 95
# len loss: 50 -- len labels: 51
# len loss: 460 -- len labels: 461
# len loss: 207 -- len labels: 208
# len loss: 410 -- len labels: 411
# len loss: 858 -- len labels: 859
# len loss: 576 -- len labels: 577
# len loss: 258 -- len labels: 259
# len loss: 395 -- len labels: 396
# len loss: 356 -- len labels: 357
# len loss: 758 -- len labels: 759
# len loss: 598 -- len labels: 599
# len loss: 590 -- len labels: 591
# len loss: 46 -- len labels: 47
# len loss: 172 -- len labels: 173
# len loss: 371 -- len labels: 372
# len loss: 300 -- len labels: 301
# len loss: 563 -- len labels: 564
# len loss: 588 -- len labels: 589
# len loss: 388 -- len labels: 389
# len loss: 282 -- len labels: 283
# len loss: 1437 -- len labels: 1438
# len loss: 290 -- len labels: 291
# len loss: 297 -- len labels: 298
# len loss: 590 -- len labels: 591
# len loss: 484 -- len labels: 485
# len loss: 720 -- len labels: 721
# len loss: 344 -- len labels: 345
# len loss: 431 -- len labels: 432
# len loss: 591 -- len labels: 592
# len loss: 634 -- len labels: 635
# len loss: 59 -- len labels: 60
# len loss: 714 -- len labels: 715
# len loss: 460 -- len labels: 461
# len loss: 246 -- len labels: 247
# len loss: 1065 -- len labels: 1066
# len loss: 152 -- len labels: 153
# len loss: 130 -- len labels: 131
# len loss: 1332 -- len labels: 1333
# len loss: 399 -- len labels: 400
# len loss: 365 -- len labels: 366
# len loss: 1070 -- len labels: 1071
# len loss: 878 -- len labels: 879
# len loss: 129 -- len labels: 130
# len loss: 440 -- len labels: 441
# len loss: 680 -- len labels: 681
# len loss: 120 -- len labels: 121
# len loss: 665 -- len labels: 666
# len loss: 355 -- len labels: 356
# len loss: 715 -- len labels: 716
# len loss: 605 -- len labels: 606
# len loss: 645 -- len labels: 646
# len loss: 176 -- len labels: 177
# len loss: 183 -- len labels: 184
# len loss: 414 -- len labels: 415
# len loss: 228 -- len labels: 229
# len loss: 845 -- len labels: 846
# len loss: 67 -- len labels: 68
# len loss: 403 -- len labels: 404
# len loss: 617 -- len labels: 618
# len loss: 292 -- len labels: 293
# len loss: 764 -- len labels: 765
# len loss: 429 -- len labels: 430
# len loss: 255 -- len labels: 256
# len loss: 353 -- len labels: 354
# len loss: 768 -- len labels: 769
# len loss: 408 -- len labels: 409
# len loss: 515 -- len labels: 516
# len loss: 1790 -- len labels: 1791
# len loss: 571 -- len labels: 572
# len loss: 1086 -- len labels: 1087
# len loss: 73 -- len labels: 74
# len loss: 543 -- len labels: 544
# len loss: 1751 -- len labels: 1752
# len loss: 545 -- len labels: 546
# len loss: 103 -- len labels: 104
# len loss: 507 -- len labels: 508
# len loss: 155 -- len labels: 156
# len loss: 385 -- len labels: 386
# len loss: 124 -- len labels: 125
# len loss: 354 -- len labels: 355
# len loss: 87 -- len labels: 88
# len loss: 92 -- len labels: 93
# len loss: 364 -- len labels: 365
# len loss: 414 -- len labels: 415
# len loss: 173 -- len labels: 174
# len loss: 612 -- len labels: 613
# len loss: 458 -- len labels: 459
# len loss: 363 -- len labels: 364
# len loss: 347 -- len labels: 348
# len loss: 450 -- len labels: 451
# len loss: 430 -- len labels: 431
# len loss: 244 -- len labels: 245
# len loss: 1115 -- len labels: 1116
# len loss: 179 -- len labels: 180
# len loss: 417 -- len labels: 418
# len loss: 335 -- len labels: 336
# len loss: 81 -- len labels: 82
# len loss: 545 -- len labels: 546
# len loss: 244 -- len labels: 245
# len loss: 439 -- len labels: 440
# len loss: 749 -- len labels: 750
# len loss: 488 -- len labels: 489
# len loss: 526 -- len labels: 527
# len loss: 708 -- len labels: 709
# len loss: 537 -- len labels: 538
# len loss: 474 -- len labels: 475
# len loss: 806 -- len labels: 807
# len loss: 991 -- len labels: 992
# len loss: 298 -- len labels: 299
# len loss: 491 -- len labels: 492
# len loss: 1327 -- len labels: 1328
# len loss: 1170 -- len labels: 1171
# len loss: 571 -- len labels: 572
# len loss: 93 -- len labels: 94
# len loss: 627 -- len labels: 628
# len loss: 141 -- len labels: 142
# len loss: 809 -- len labels: 810
# len loss: 167 -- len labels: 168
# len loss: 293 -- len labels: 294
# len loss: 787 -- len labels: 788
# len loss: 289 -- len labels: 290
# len loss: 431 -- len labels: 432
# len loss: 191 -- len labels: 192
# len loss: 472 -- len labels: 473
# len loss: 485 -- len labels: 486
# len loss: 330 -- len labels: 331
# len loss: 498 -- len labels: 499
# len loss: 482 -- len labels: 483
# len loss: 135 -- len labels: 136
# len loss: 131 -- len labels: 132
# len loss: 657 -- len labels: 658
# len loss: 125 -- len labels: 126
# len loss: 809 -- len labels: 810
# len loss: 333 -- len labels: 334
# len loss: 293 -- len labels: 294
# len loss: 411 -- len labels: 412
# len loss: 144 -- len labels: 145
# len loss: 861 -- len labels: 862
# len loss: 684 -- len labels: 685
# len loss: 662 -- len labels: 663
# len loss: 277 -- len labels: 278
# len loss: 464 -- len labels: 465
# len loss: 796 -- len labels: 797
# len loss: 395 -- len labels: 396
# len loss: 565 -- len labels: 566
# len loss: 521 -- len labels: 522
# len loss: 107 -- len labels: 108
# len loss: 189 -- len labels: 190
# len loss: 1777 -- len labels: 1778
# len loss: 431 -- len labels: 432
# len loss: 543 -- len labels: 544
# len loss: 524 -- len labels: 525
# len loss: 344 -- len labels: 345
# len loss: 116 -- len labels: 117
# len loss: 61 -- len labels: 62
# len loss: 466 -- len labels: 467
# len loss: 1138 -- len labels: 1139
# len loss: 648 -- len labels: 649
# len loss: 180 -- len labels: 181
# len loss: 455 -- len labels: 456
# len loss: 61 -- len labels: 62
# len loss: 539 -- len labels: 540
# len loss: 371 -- len labels: 372
# len loss: 153 -- len labels: 154
# len loss: 111 -- len labels: 112
# len loss: 666 -- len labels: 667
# len loss: 472 -- len labels: 473
# len loss: 476 -- len labels: 477
# len loss: 1440 -- len labels: 1441
# len loss: 131 -- len labels: 132
# len loss: 453 -- len labels: 454
# len loss: 488 -- len labels: 489
# len loss: 525 -- len labels: 526
# len loss: 158 -- len labels: 159
# len loss: 110 -- len labels: 111
# len loss: 394 -- len labels: 395
# len loss: 895 -- len labels: 896
# len loss: 1061 -- len labels: 1062
# len loss: 224 -- len labels: 225
# len loss: 550 -- len labels: 551
# len loss: 518 -- len labels: 519
# len loss: 170 -- len labels: 171
# len loss: 358 -- len labels: 359
# len loss: 781 -- len labels: 782
# len loss: 263 -- len labels: 264
# len loss: 148 -- len labels: 149
# len loss: 1533 -- len labels: 1534
# len loss: 477 -- len labels: 478
# len loss: 312 -- len labels: 313
# len loss: 527 -- len labels: 528
# len loss: 981 -- len labels: 982
# len loss: 195 -- len labels: 196
# len loss: 44 -- len labels: 45
# len loss: 184 -- len labels: 185
# len loss: 117 -- len labels: 118
# len loss: 448 -- len labels: 449
# len loss: 576 -- len labels: 577
# len loss: 86 -- len labels: 87
# len loss: 533 -- len labels: 534
# len loss: 92 -- len labels: 93
# len loss: 478 -- len labels: 479
# len loss: 698 -- len labels: 699
# len loss: 147 -- len labels: 148
# len loss: 439 -- len labels: 440
# len loss: 334 -- len labels: 335
# len loss: 633 -- len labels: 634
# len loss: 53 -- len labels: 54
# len loss: 101 -- len labels: 102
# len loss: 204 -- len labels: 205
# len loss: 468 -- len labels: 469
# len loss: 142 -- len labels: 143
# len loss: 450 -- len labels: 451
# len loss: 510 -- len labels: 511
# len loss: 81 -- len labels: 82
# len loss: 262 -- len labels: 263
# len loss: 474 -- len labels: 475
# len loss: 442 -- len labels: 443
# len loss: 746 -- len labels: 747
# len loss: 280 -- len labels: 281
# len loss: 322 -- len labels: 323
# len loss: 291 -- len labels: 292
# len loss: 309 -- len labels: 310
# len loss: 324 -- len labels: 325
# len loss: 250 -- len labels: 251
# len loss: 188 -- len labels: 189
# len loss: 322 -- len labels: 323
# len loss: 177 -- len labels: 178
# len loss: 222 -- len labels: 223
# len loss: 413 -- len labels: 414
# len loss: 379 -- len labels: 380
# len loss: 584 -- len labels: 585
# len loss: 895 -- len labels: 896
# len loss: 277 -- len labels: 278
# len loss: 446 -- len labels: 447
# len loss: 383 -- len labels: 384
# len loss: 439 -- len labels: 440
# len loss: 790 -- len labels: 791
# len loss: 414 -- len labels: 415
# len loss: 332 -- len labels: 333
# len loss: 551 -- len labels: 552
# len loss: 922 -- len labels: 923
# len loss: 889 -- len labels: 890
# len loss: 200 -- len labels: 201
# len loss: 495 -- len labels: 496
# len loss: 781 -- len labels: 782
# len loss: 243 -- len labels: 244
# len loss: 563 -- len labels: 564
# len loss: 598 -- len labels: 599
# len loss: 621 -- len labels: 622
# len loss: 757 -- len labels: 758
# len loss: 605 -- len labels: 606
# len loss: 325 -- len labels: 326
# len loss: 887 -- len labels: 888
# len loss: 1210 -- len labels: 1211
# len loss: 455 -- len labels: 456
# len loss: 152 -- len labels: 153
# len loss: 498 -- len labels: 499
# len loss: 114 -- len labels: 115
# len loss: 492 -- len labels: 493
# len loss: 545 -- len labels: 546
# len loss: 767 -- len labels: 768
# len loss: 447 -- len labels: 448
# len loss: 874 -- len labels: 875
# len loss: 376 -- len labels: 377
# len loss: 158 -- len labels: 159
# len loss: 581 -- len labels: 582
# len loss: 123 -- len labels: 124
# len loss: 234 -- len labels: 235
# len loss: 168 -- len labels: 169
# len loss: 522 -- len labels: 523
# len loss: 427 -- len labels: 428
# len loss: 89 -- len labels: 90
# len loss: 442 -- len labels: 443
# len loss: 582 -- len labels: 583
# len loss: 498 -- len labels: 499
# len loss: 533 -- len labels: 534
# len loss: 1396 -- len labels: 1397
# len loss: 639 -- len labels: 640
# len loss: 498 -- len labels: 499
# len loss: 862 -- len labels: 863
# len loss: 354 -- len labels: 355
# len loss: 218 -- len labels: 219
# len loss: 400 -- len labels: 401
# len loss: 314 -- len labels: 315
# len loss: 346 -- len labels: 347
# len loss: 123 -- len labels: 124
# len loss: 764 -- len labels: 765
# len loss: 448 -- len labels: 449
# len loss: 826 -- len labels: 827
# len loss: 658 -- len labels: 659
# len loss: 386 -- len labels: 387
# len loss: 561 -- len labels: 562
# len loss: 115 -- len labels: 116
# len loss: 874 -- len labels: 875
# len loss: 62 -- len labels: 63
# len loss: 417 -- len labels: 418
# len loss: 193 -- len labels: 194
# len loss: 509 -- len labels: 510
# len loss: 819 -- len labels: 820
# len loss: 268 -- len labels: 269
# len loss: 1086 -- len labels: 1087
# len loss: 262 -- len labels: 263
# len loss: 160 -- len labels: 161
# len loss: 338 -- len labels: 339
# len loss: 568 -- len labels: 569
# len loss: 623 -- len labels: 624
# len loss: 212 -- len labels: 213
# len loss: 543 -- len labels: 544
# len loss: 175 -- len labels: 176
# len loss: 440 -- len labels: 441
# len loss: 36 -- len labels: 37
# len loss: 955 -- len labels: 956
# len loss: 717 -- len labels: 718
# len loss: 628 -- len labels: 629
# len loss: 346 -- len labels: 347
# len loss: 841 -- len labels: 842
# len loss: 988 -- len labels: 989
# len loss: 631 -- len labels: 632
# len loss: 369 -- len labels: 370
# len loss: 491 -- len labels: 492
# len loss: 575 -- len labels: 576
# len loss: 415 -- len labels: 416
# len loss: 1596 -- len labels: 1597
# len loss: 544 -- len labels: 545
# len loss: 147 -- len labels: 148
# len loss: 137 -- len labels: 138
# len loss: 673 -- len labels: 674
# len loss: 450 -- len labels: 451
# len loss: 706 -- len labels: 707
# len loss: 145 -- len labels: 146
# len loss: 660 -- len labels: 661
# len loss: 879 -- len labels: 880
# len loss: 207 -- len labels: 208
# len loss: 749 -- len labels: 750
# len loss: 169 -- len labels: 170
# len loss: 542 -- len labels: 543
# len loss: 644 -- len labels: 645
# len loss: 355 -- len labels: 356
# len loss: 391 -- len labels: 392
# len loss: 722 -- len labels: 723
# len loss: 294 -- len labels: 295
# len loss: 199 -- len labels: 200
# len loss: 450 -- len labels: 451
# len loss: 82 -- len labels: 83
# len loss: 129 -- len labels: 130
# len loss: 77 -- len labels: 78
# len loss: 1465 -- len labels: 1466
# len loss: 395 -- len labels: 396
# len loss: 340 -- len labels: 341
# len loss: 347 -- len labels: 348
# len loss: 400 -- len labels: 401
# len loss: 328 -- len labels: 329
# len loss: 315 -- len labels: 316
# len loss: 136 -- len labels: 137
# len loss: 29 -- len labels: 30
# len loss: 1034 -- len labels: 1035
# len loss: 390 -- len labels: 391
# len loss: 296 -- len labels: 297
# len loss: 1160 -- len labels: 1161
# len loss: 453 -- len labels: 454
# len loss: 378 -- len labels: 379
# len loss: 241 -- len labels: 242
# len loss: 521 -- len labels: 522
# len loss: 472 -- len labels: 473
# len loss: 1116 -- len labels: 1117
# len loss: 519 -- len labels: 520
# len loss: 758 -- len labels: 759
# len loss: 539 -- len labels: 540
# len loss: 422 -- len labels: 423
# len loss: 313 -- len labels: 314
# len loss: 1343 -- len labels: 1344
# len loss: 462 -- len labels: 463
# len loss: 444 -- len labels: 445
# len loss: 522 -- len labels: 523
# len loss: 622 -- len labels: 623
# len loss: 599 -- len labels: 600
# len loss: 542 -- len labels: 543
# len loss: 1595 -- len labels: 1596
# len loss: 225 -- len labels: 226
# len loss: 686 -- len labels: 687
# len loss: 691 -- len labels: 692
# len loss: 921 -- len labels: 922
# len loss: 504 -- len labels: 505
# len loss: 315 -- len labels: 316
# len loss: 464 -- len labels: 465
# len loss: 224 -- len labels: 225
# len loss: 1165 -- len labels: 1166
# len loss: 407 -- len labels: 408
# len loss: 631 -- len labels: 632
# len loss: 504 -- len labels: 505
# len loss: 249 -- len labels: 250
# len loss: 261 -- len labels: 262
# len loss: 459 -- len labels: 460
# len loss: 496 -- len labels: 497
# len loss: 79 -- len labels: 80
# len loss: 1275 -- len labels: 1276
# len loss: 292 -- len labels: 293
# len loss: 578 -- len labels: 579
# len loss: 378 -- len labels: 379
# len loss: 1749 -- len labels: 1750
# len loss: 611 -- len labels: 612
# len loss: 358 -- len labels: 359
# len loss: 686 -- len labels: 687
# len loss: 123 -- len labels: 124
# len loss: 547 -- len labels: 548
# len loss: 132 -- len labels: 133
# len loss: 438 -- len labels: 439
# len loss: 411 -- len labels: 412
# len loss: 584 -- len labels: 585
# len loss: 708 -- len labels: 709
# len loss: 246 -- len labels: 247
# len loss: 975 -- len labels: 976
# len loss: 522 -- len labels: 523
# len loss: 279 -- len labels: 280
# len loss: 882 -- len labels: 883
# len loss: 785 -- len labels: 786
# len loss: 238 -- len labels: 239
# len loss: 1334 -- len labels: 1335
# len loss: 222 -- len labels: 223
# len loss: 91 -- len labels: 92
# len loss: 436 -- len labels: 437
# len loss: 123 -- len labels: 124
# len loss: 849 -- len labels: 850
# len loss: 203 -- len labels: 204
# len loss: 323 -- len labels: 324
# len loss: 544 -- len labels: 545
# len loss: 326 -- len labels: 327
# len loss: 522 -- len labels: 523
# len loss: 1396 -- len labels: 1397
# len loss: 1164 -- len labels: 1165
# len loss: 602 -- len labels: 603
# len loss: 575 -- len labels: 576
# len loss: 412 -- len labels: 413
# len loss: 770 -- len labels: 771
# len loss: 589 -- len labels: 590
# len loss: 546 -- len labels: 547
# len loss: 477 -- len labels: 478
# len loss: 108 -- len labels: 109
# len loss: 402 -- len labels: 403
# len loss: 158 -- len labels: 159
# len loss: 774 -- len labels: 775
# len loss: 899 -- len labels: 900
# len loss: 110 -- len labels: 111
# len loss: 340 -- len labels: 341
# len loss: 94 -- len labels: 95
# len loss: 545 -- len labels: 546
# len loss: 239 -- len labels: 240
# len loss: 427 -- len labels: 428
# len loss: 1673 -- len labels: 1674
# len loss: 386 -- len labels: 387
# len loss: 612 -- len labels: 613
# len loss: 772 -- len labels: 773
# len loss: 323 -- len labels: 324
# len loss: 481 -- len labels: 482
# len loss: 308 -- len labels: 309
# len loss: 187 -- len labels: 188
# len loss: 301 -- len labels: 302
# len loss: 231 -- len labels: 232
# len loss: 1797 -- len labels: 1798
# len loss: 306 -- len labels: 307
# len loss: 587 -- len labels: 588
# len loss: 395 -- len labels: 396
# len loss: 444 -- len labels: 445
# len loss: 212 -- len labels: 213
# len loss: 345 -- len labels: 346
# len loss: 502 -- len labels: 503
# len loss: 1805 -- len labels: 1806
# len loss: 213 -- len labels: 214
# len loss: 1145 -- len labels: 1146
# len loss: 984 -- len labels: 985
# len loss: 569 -- len labels: 570
# len loss: 542 -- len labels: 543
# len loss: 857 -- len labels: 858
# len loss: 432 -- len labels: 433
# len loss: 375 -- len labels: 376
# len loss: 1517 -- len labels: 1518
# len loss: 1268 -- len labels: 1269
# len loss: 219 -- len labels: 220
# len loss: 1014 -- len labels: 1015
# len loss: 538 -- len labels: 539
# len loss: 460 -- len labels: 461
# len loss: 184 -- len labels: 185
# len loss: 831 -- len labels: 832
# len loss: 461 -- len labels: 462
# len loss: 449 -- len labels: 450
# len loss: 612 -- len labels: 613
# len loss: 258 -- len labels: 259
# len loss: 632 -- len labels: 633
# len loss: 73 -- len labels: 74
# len loss: 346 -- len labels: 347
# len loss: 119 -- len labels: 120
# len loss: 944 -- len labels: 945
# len loss: 400 -- len labels: 401
# len loss: 276 -- len labels: 277
# len loss: 498 -- len labels: 499
# len loss: 740 -- len labels: 741
# len loss: 193 -- len labels: 194
# len loss: 1048 -- len labels: 1049
# len loss: 371 -- len labels: 372
# len loss: 503 -- len labels: 504
# len loss: 737 -- len labels: 738
# len loss: 519 -- len labels: 520
# len loss: 106 -- len labels: 107
# len loss: 714 -- len labels: 715
# len loss: 615 -- len labels: 616
# len loss: 408 -- len labels: 409
# len loss: 760 -- len labels: 761
# len loss: 51 -- len labels: 52
# len loss: 365 -- len labels: 366
# len loss: 365 -- len labels: 366
# len loss: 899 -- len labels: 900
# len loss: 405 -- len labels: 406
# len loss: 454 -- len labels: 455
# len loss: 919 -- len labels: 920
# len loss: 497 -- len labels: 498
# len loss: 524 -- len labels: 525
# len loss: 594 -- len labels: 595
# len loss: 441 -- len labels: 442
# len loss: 572 -- len labels: 573
# len loss: 104 -- len labels: 105
# len loss: 146 -- len labels: 147
# len loss: 200 -- len labels: 201
# len loss: 735 -- len labels: 736
# len loss: 516 -- len labels: 517
# len loss: 760 -- len labels: 761
# len loss: 487 -- len labels: 488
# len loss: 591 -- len labels: 592
# len loss: 114 -- len labels: 115
# len loss: 431 -- len labels: 432
# len loss: 354 -- len labels: 355
# len loss: 804 -- len labels: 805
# len loss: 949 -- len labels: 950
# len loss: 514 -- len labels: 515
# len loss: 1051 -- len labels: 1052
# len loss: 91 -- len labels: 92
# len loss: 339 -- len labels: 340
# len loss: 393 -- len labels: 394
# len loss: 532 -- len labels: 533
# len loss: 132 -- len labels: 133
# len loss: 593 -- len labels: 594
# len loss: 343 -- len labels: 344
# len loss: 369 -- len labels: 370
# len loss: 1076 -- len labels: 1077
# len loss: 1505 -- len labels: 1506
# len loss: 529 -- len labels: 530
# len loss: 269 -- len labels: 270
# len loss: 967 -- len labels: 968
# len loss: 224 -- len labels: 225
# len loss: 102 -- len labels: 103
# len loss: 864 -- len labels: 865
# len loss: 371 -- len labels: 372
# len loss: 79 -- len labels: 80
# len loss: 248 -- len labels: 249
# len loss: 104 -- len labels: 105
# len loss: 530 -- len labels: 531
# len loss: 209 -- len labels: 210
# len loss: 142 -- len labels: 143
# len loss: 475 -- len labels: 476
# len loss: 368 -- len labels: 369
# len loss: 244 -- len labels: 245
# len loss: 169 -- len labels: 170
# len loss: 980 -- len labels: 981
# len loss: 537 -- len labels: 538
# len loss: 533 -- len labels: 534
# len loss: 321 -- len labels: 322
# len loss: 1514 -- len labels: 1515
# len loss: 624 -- len labels: 625
# len loss: 1720 -- len labels: 1721
# len loss: 320 -- len labels: 321
# len loss: 341 -- len labels: 342
# len loss: 416 -- len labels: 417
# len loss: 242 -- len labels: 243
# len loss: 261 -- len labels: 262
# len loss: 239 -- len labels: 240
# len loss: 165 -- len labels: 166
# len loss: 471 -- len labels: 472
# len loss: 534 -- len labels: 535
# len loss: 984 -- len labels: 985
# len loss: 616 -- len labels: 617
# len loss: 439 -- len labels: 440
# len loss: 178 -- len labels: 179
# len loss: 349 -- len labels: 350
# len loss: 195 -- len labels: 196
# len loss: 420 -- len labels: 421
# len loss: 398 -- len labels: 399
# len loss: 376 -- len labels: 377
# len loss: 459 -- len labels: 460
# len loss: 1137 -- len labels: 1138
# len loss: 637 -- len labels: 638
# len loss: 307 -- len labels: 308
# len loss: 924 -- len labels: 925
# len loss: 171 -- len labels: 172
# len loss: 769 -- len labels: 770
# len loss: 474 -- len labels: 475
# len loss: 97 -- len labels: 98
# len loss: 461 -- len labels: 462
# len loss: 579 -- len labels: 580
# len loss: 173 -- len labels: 174
# len loss: 308 -- len labels: 309
# len loss: 623 -- len labels: 624
# len loss: 336 -- len labels: 337
# len loss: 100 -- len labels: 101
# len loss: 196 -- len labels: 197
# len loss: 491 -- len labels: 492
# len loss: 382 -- len labels: 383
# len loss: 459 -- len labels: 460
# len loss: 222 -- len labels: 223
# len loss: 539 -- len labels: 540
# len loss: 639 -- len labels: 640
# len loss: 404 -- len labels: 405
# len loss: 306 -- len labels: 307
# len loss: 508 -- len labels: 509
# len loss: 140 -- len labels: 141
# len loss: 788 -- len labels: 789
# len loss: 1551 -- len labels: 1552
# len loss: 401 -- len labels: 402
# len loss: 622 -- len labels: 623
# len loss: 562 -- len labels: 563
# len loss: 337 -- len labels: 338
# len loss: 1532 -- len labels: 1533
# len loss: 410 -- len labels: 411
# len loss: 641 -- len labels: 642
# len loss: 1407 -- len labels: 1408
# len loss: 579 -- len labels: 580
# len loss: 497 -- len labels: 498
# len loss: 125 -- len labels: 126
# len loss: 285 -- len labels: 286
# len loss: 394 -- len labels: 395
# len loss: 880 -- len labels: 881
# len loss: 298 -- len labels: 299
# len loss: 68 -- len labels: 69
# len loss: 418 -- len labels: 419
# len loss: 90 -- len labels: 91
# len loss: 898 -- len labels: 899
# len loss: 532 -- len labels: 533
# len loss: 116 -- len labels: 117
# len loss: 284 -- len labels: 285
# len loss: 602 -- len labels: 603
# len loss: 418 -- len labels: 419
# len loss: 710 -- len labels: 711
# len loss: 366 -- len labels: 367
# len loss: 889 -- len labels: 890
# len loss: 566 -- len labels: 567
# len loss: 701 -- len labels: 702
# len loss: 95 -- len labels: 96
# len loss: 587 -- len labels: 588
# len loss: 324 -- len labels: 325
# len loss: 458 -- len labels: 459
# len loss: 360 -- len labels: 361
# len loss: 135 -- len labels: 136
# len loss: 336 -- len labels: 337
# len loss: 856 -- len labels: 857
# len loss: 601 -- len labels: 602
# len loss: 395 -- len labels: 396
# len loss: 758 -- len labels: 759
# len loss: 972 -- len labels: 973
# len loss: 642 -- len labels: 643
# len loss: 39 -- len labels: 40
# len loss: 438 -- len labels: 439
# len loss: 123 -- len labels: 124
# len loss: 239 -- len labels: 240
# len loss: 749 -- len labels: 750
# len loss: 98 -- len labels: 99
# len loss: 85 -- len labels: 86
# len loss: 241 -- len labels: 242
# len loss: 348 -- len labels: 349
# len loss: 194 -- len labels: 195
# len loss: 90 -- len labels: 91
# len loss: 350 -- len labels: 351
# len loss: 296 -- len labels: 297
# len loss: 523 -- len labels: 524
# len loss: 201 -- len labels: 202
# len loss: 65 -- len labels: 66
# len loss: 291 -- len labels: 292
# len loss: 966 -- len labels: 967
# len loss: 584 -- len labels: 585
# len loss: 85 -- len labels: 86
# len loss: 751 -- len labels: 752
# len loss: 754 -- len labels: 755
# len loss: 299 -- len labels: 300
# len loss: 692 -- len labels: 693
# len loss: 280 -- len labels: 281
# len loss: 105 -- len labels: 106
# len loss: 89 -- len labels: 90
# len loss: 462 -- len labels: 463
# len loss: 781 -- len labels: 782
# len loss: 1087 -- len labels: 1088
# len loss: 971 -- len labels: 972
# len loss: 254 -- len labels: 255
# len loss: 533 -- len labels: 534
# len loss: 823 -- len labels: 824
# len loss: 559 -- len labels: 560
# len loss: 872 -- len labels: 873
# len loss: 514 -- len labels: 515
# len loss: 475 -- len labels: 476
# len loss: 1406 -- len labels: 1407
# len loss: 101 -- len labels: 102
# len loss: 439 -- len labels: 440
# len loss: 145 -- len labels: 146
# len loss: 688 -- len labels: 689
# len loss: 1361 -- len labels: 1362
# len loss: 340 -- len labels: 341
# len loss: 490 -- len labels: 491
# len loss: 582 -- len labels: 583
# len loss: 332 -- len labels: 333
# len loss: 312 -- len labels: 313
# len loss: 355 -- len labels: 356
# len loss: 305 -- len labels: 306
# len loss: 102 -- len labels: 103
# len loss: 497 -- len labels: 498
# len loss: 527 -- len labels: 528
# len loss: 152 -- len labels: 153

# %%
all_token_count
selected_sample_labels_count = sum(
    sum(1 for label in sample if label != -100) for sample in selected_sample_labels
)

selected_global_labels_count = sum(
    sum(1 for label in sample if label != -100) for sample in selected_global_labels
)

print(f"selected_sample_labels_count: {selected_sample_labels_count}")
print(f"selected_global_labels_count: {selected_global_labels_count}")
# Out:
# selected_sample_labels_count: 486626
# selected_global_labels_count: 486626

# %%
for i, j in select_global_tokens_indices[:100]:
    print(loss_diff[i][j-1])
# Out:
# 8.806870087981224
# 7.24859094619751
# 5.935330390930176
# 5.923524379730225
# 5.831694602966309
# 5.696369171142578
# 5.599660396575928
# 5.513375282287598
# 5.452551603317261
# 5.446721792221069
# 5.339729070663452
# 5.325538635253906
# 5.273169368505478
# 5.250312805175781
# 5.1521932780742645
# 5.13873291015625
# 5.120546251535416
# 5.079023122787476
# 5.059002876281738
# 5.033239841461182
# 4.9899067878723145
# 4.970749855041504
# 4.970494270324707
# 4.877408921718597
# 4.873149871826172
# 4.8416032791137695
# 4.835258483886719
# 4.813791990280151
# 4.802964925765991
# 4.719444274902344
# 4.6886162757873535
# 4.616905689239502
# 4.6069276332855225
# 4.573083877563477
# 4.572339057922363
# 4.5693793296813965
# 4.558010935783386
# 4.553904183208942
# 4.536604881286621
# 4.53176212310791
# 4.52959406375885
# 4.526368111371994
# 4.510976791381836
# 4.508610963821411
# 4.50351881980896
# 4.497838497161865
# 4.497535824775696
# 4.488606750965118
# 4.387574315071106
# 4.382802486419678
# 4.359728693962097
# 4.353085041046143
# 4.350334644317627
# 4.335271120071411
# 4.323821067810059
# 4.305021286010742
# 4.296273827552795
# 4.280084133148193
# 4.256967067718506
# 4.245144844055176
# 4.24263858795166
# 4.219273090362549
# 4.208210319280624
# 4.202213644981384
# 4.162072509527206
# 4.1553051471710205
# 4.138089895248413
# 4.129452884197235
# 4.129452884197235
# 4.124095439910889
# 4.119379043579102
# 4.081131458282471
# 4.073646247386932
# 4.054571628570557
# 4.04991090297699
# 4.037196636199951
# 4.023108959197998
# 4.019522726535797
# 4.014820992946625
# 4.0117223262786865
# 3.9977147579193115
# 3.992866039276123
# 3.9920674562454224
# 3.980219006538391
# 3.974944978952408
# 3.968327522277832
# 3.945525676012039
# 3.9422712326049805
# 3.9379045963287354
# 3.9196821451187134
# 3.9147613048553467
# 3.906702905893326
# 3.900832176208496
# 3.900268793106079
# 3.893949270248413
# 3.891868829727173
# 3.8763813972473145
# 3.875584363937378
# 3.870199203491211
# 3.8676251769065857

# %%
select_sample_tokens_indices = []
loss_selected = []
for diff in loss_diff:
    values, indices = torch.topk(torch.tensor(diff), k=int(len(diff) * data_prop), largest=True)
    select_sample_tokens_indices.append((indices).tolist()) 
    loss_selected.extend(values.tolist())
    # print(values.tolist())

# sorted(flattened, key=lambda x: x[0], reverse=True)[:k]
sorted(loss_selected, reverse=True)[:100]
# Out:
# [8.806870460510254,
#  7.24859094619751,
#  5.935330390930176,
#  5.923524379730225,
#  5.831694602966309,
#  5.696369171142578,
#  5.599660396575928,
#  5.513375282287598,
#  5.45255184173584,
#  5.446722030639648,
#  5.339729309082031,
#  5.325538635253906,
#  5.27316951751709,
#  5.250312805175781,
#  5.152193069458008,
#  5.13873291015625,
#  5.120546340942383,
#  5.079023361206055,
#  5.059002876281738,
#  5.033239841461182,
#  4.9899067878723145,
#  4.970749855041504,
#  4.970494270324707,
#  4.877408981323242,
#  4.873149871826172,
#  4.8416032791137695,
#  4.835258483886719,
#  4.8137922286987305,
#  4.80296516418457,
#  4.719444274902344,
#  4.6886162757873535,
#  4.616905689239502,
#  4.606927871704102,
#  4.573083877563477,
#  4.572339057922363,
#  4.5693793296813965,
#  4.558011054992676,
#  4.553904056549072,
#  4.536604881286621,
#  4.53176212310791,
#  4.5295939445495605,
#  4.526368141174316,
#  4.510976791381836,
#  4.508610725402832,
#  4.503519058227539,
#  4.497838497161865,
#  4.497535705566406,
#  4.488606929779053,
#  4.387574195861816,
#  4.382802486419678,
#  4.359728813171387,
#  4.353085041046143,
#  4.350334644317627,
#  4.335270881652832,
#  4.323821067810059,
#  4.305021286010742,
#  4.296273708343506,
#  4.280084133148193,
#  4.256967067718506,
#  4.245144844055176,
#  4.24263858795166,
#  4.219273090362549,
#  4.208210468292236,
#  4.202213764190674,
#  4.162072658538818,
#  4.155304908752441,
#  4.138090133666992,
#  4.129452705383301,
#  4.129452705383301,
#  4.124095439910889,
#  4.119379043579102,
#  4.081131458282471,
#  4.073646068572998,
#  4.054571628570557,
#  4.049911022186279,
#  4.037196636199951,
#  4.023108959197998,
#  4.019522666931152,
#  4.0148210525512695,
#  4.011722564697266,
#  3.9977147579193115,
#  3.992866039276123,
#  3.992067337036133,
#  3.9802188873291016,
#  3.974945068359375,
#  3.968327522277832,
#  3.945525646209717,
#  3.9422712326049805,
#  3.9379045963287354,
#  3.919682025909424,
#  3.9147613048553467,
#  3.906702995300293,
#  3.900832176208496,
#  3.900268793106079,
#  3.893949270248413,
#  3.891868829727173,
#  3.8763813972473145,
#  3.875584363937378,
#  3.870199203491211,
#  3.8676252365112305]
